# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# # مقدمة مختصرة للحوسبة الكمومية باستخدام كيسكت (Qiskit) — بناء دارتك الكمومية الأولى!
# ##### من قبل حسان الحصيني، 25 يوليو 2025
# ###### توضيح: التعليقات بالخلايا مكتوبة بالعربية والإنجليزية لتعويض ضعف دعم بايثون للعربية
# </div>
#
# ###### Note: Comments are written in both Arabic and English to compensate for Python's limited Arabic support
# <div dir="rtl" style="text-align: right;">
#
#    ##### إخلاء مسؤولية: كل الشروحات، التعديلات، والترجمة في المذكرة تعكس فهمي الشخصي ولا تمثل أيّ من المؤلفين الأصليين أو المراجع المقتبس منها.
# </div>
#
# ##### Disclaimer: The explanations, adaptations, Translations, and edits in this notebook reflect my own understanding and do not represent the original authors or sources referenced.
#
# <div dir="rtl" style="text-align: right;">
# هذه المذكرة تقدم مقدمة مختصرة، واضحة، وموجزة لمفاهيم الحوسبة الكمومية وميكانيكا الكم الأساسية. لقد صممت المذكرة لتكون مناسبة للمبتدئين بينما تكون واضحة أكاديميًا، مما يجعلها مناسبة للمتعلمين من خلفيات مختلفة.
# </div>
#
#
#
# <div dir="rtl" style="text-align: right;">
#
# #### المواضيع الرئيسية التي تمت تغطيتها في المذكرة هي:
# * ماهي الحوسبة الكمومية؟
# * التراكب والتشابك الكمومي
# * البوابات الكمومية
# * بناء دائرتك الكمومية الأولى باستخدام كيسكت من الصفر
#
#
#
# </div>
#
# ##### This notebook is available in two versions: English and Arabic.
# <div dir="rtl" style="text-align: right;">
#
# ##### هذه المذكرة تتوفر باللغتين العربية والإنجليزية.
# </div>
#
#
# <div dir="rtl" style="text-align: right;">
# في نهاية المذكرة، ستجد مجموعة من المصادر المفيدة لتكمل رحلتك الكّمومية.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### كيفية تشغيل هذه المذكرة
# </div>
#
# <div dir="rtl" style="text-align: right;">
# يمكن تشغيل هذه المذكرة إما "محليًا" (في حاسوبك الشخصي) أو باستخدام بيئات سحابية (Cloud-based environments) مثل جوجل كولاب (Google Colab).
# للإعداد المحلي، تأكد من تثبيت بايثون (Python 3.10  فما فوق) وجوبتور(Jupyter)، ثم شغل خلية التثبيت لإعداد كيسكت (Qiskit).
# إذا كنت تفضل تشغيله على الإنترنت، فما عليك سوى فتح هذه المذكرة في "جوجل كولاب" وتشغيل الخلايا بعد تشغيل خلية تثبيت كيسكت (في فصل "إعداد بيئة التطوير").
#
# </div>
#
# <div dir="rtl" style="text-align: right;">
#
# ## 📘الفهرس
#
# ##### الفصل 0 — إعداد بيئة التطوير
#
# ##### الفصل 1 — مقدمة مختصرة للحوسبة الكمومية
# ###### جلسة 1.1: البت الكلاسيكي مقابل البت الكمومي (الكيوبت)
#
# ###### جلسة 1.2: التراكب
#
# ###### جلسة 1.3: التراكب
#
# ##### الفصل 2 — البوابات الكمومية
# ###### جلسة 2.1: بوابة X
#
# ###### جلسة 2.2: بوابة هادامارد (H)
#
# ###### • تمرين 1: تحويل التعبير الرياضي إلى دارة كمومية
#
# ###### جلسة 2.3: بوابة CNOT
# ###### • تمرين 2:  جرّب قياس دارة كمومية مكونة من كيوبتين بنفسك!
#
# ##### الفصل 3 — بناء دارتك الكمومية الأولى باستخدام كيسكت من الصفر
#
# ###### جلسة 3.1: فهم محاكي Aer
#
# ###### جلسة 3.2: حالة بيل (Bell)
#
# ###### • تمرين 3: بناء دائرتك الكمومية الأولى باستخدم كيسكت من الصفر
# ###### • محاكاة و ناتج الهيستوجرام (Histogram)
# ###### • ماذا حدث؟ (تحليل النتيجة)
#
# ##### الفصل 4 — الختام
#
# ###### جلسة 4.1: ملخص للذي تعلمته
#
# ###### جلسة 4.2: نموذج التغذية الراجعة
#
# ###### جلسة 4.3: موارد مفتوحة المصدر
#
# ###### جلسة 4.4: المراجع
#
# ###### جلسة 4.5: الوداع من صديقك الكمومي ⚛️
#
#
#
#
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## الفصل 0 — إعداد بيئة التطوير
# </div>
#
# <div dir="rtl" style="text-align: right;">
# قبل التعمق في المفاهيم الاساسية في الحوسبة الكمومية وميكانيكا الكم، سنبدأ يإعداد بيئة التطوير (development environment).
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ### أولًا نحتاج تنزيل المكتبات المطلوبة
# </div>
# <div dir="rtl" style="text-align: right;">
# كيسكت هو إطار عمل مفتوح المصدر تم تطويره بواسطة IBM لبناء ومحاكاة الدارات الكمومية.
# </div>

# %%
#Installing the required libraries
#تنزيل المكتبات المطلوبة

# Install Qiskit and upgrade to the latest version
#تنزيل كيسكت وترقيتها للإصدار الأخير
# %pip install qiskit --upgrade

# Install the Qiskit Aer library for simulation
# تنزيل مكتبة كيسكت Aer للمحاكاة
# %pip install qiskit qiskit-aer --upgrade

# Install Qiskit visualization tools
#تنزيل أدوات كيسكت للتمثيل البياني
# %pip install qiskit[visualization] --upgrade

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### ثانيًا نحتاج للتحقق مما إذا كنا نستخدم الإصدارات الصحيحة من بايثون وكيسكت
# </div>
# <div dir="rtl" style="text-align: right;">
# تأكد من أنك تستخدم:
# </div>
# <div dir="rtl" style="text-align: right;">
#     بايثون بإصدار >= `3.10+` و كيسكت بإصدار >= `2.1+` باستخدام هذه الخلية:
# </div>

# %%
#استيراد المكتبات للتحقق ما إذا كُنتَ تستخدم الإصدار الصحيح، وكذلك لاستخدام المكتبات في الجزء العملي من المذكرة
#Importing the libraries to check if you are using the right version, and using it later in the practical section in the notebook.
import sys
import qiskit
import matplotlib
print("إصدار بايثون:", sys.version) #يطبع إصدار بايثون
print("إصدار كيسكت:", qiskit.__version__) #يطبع إصدار كيسكت

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### جيد! إذا كانت إصدارات بايثون وكيسكت لديك تتوافق مع المتطلبات المذكور أعلاه، لنستمر.
# ##### إذا لم يكن الأمر كذلك، يرجى تشغيل الخلية الأولى باستخدام الأمر "pip install".
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## الفصل 1 — مقدمة مختصرة للحوسبة الكمومية
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 1.1: البتات الكلاسيكية مقابل البتات الكمومية
# </div>
# <div dir="rtl" style="text-align: right;">
# قبل أن نُقدم بإيجاز الحوسبة الكمومية، دعونا نُراجع أولًا الوحدة الأساسية للحوسبة الكلاسيكية — البتات الكلاسيكية.
# </div>
#
# <div dir="rtl" style="text-align: right;">
# يوجد البت الكلاسيكي في حالتين فقط: "0" أو "1"، ويخضع هذا الأسلوب لمبادئ الفيزياء الكلاسيكية.
# </div>
# <div dir="rtl" style="text-align: right;">
# في المقابل، الوحدة الأساسية في الحوسبة الكمومية هي البت الكّمومي (الكيوبت)، الذي يخزن المعلومات الكمومية.
# </div>
# <div dir="rtl" style="text-align: right;">
# على عكس البتات الكلاسيكية، يُمكن أن يكون الكيوبت في الحالة $|0\rangle$، أو الحالة $|1\rangle$، أو في حالة تراكب لكلتا الحالتين في آنٍ واحد.
# </div>
# <div dir="rtl" style="text-align: right;">
# تُمثل هذه الحالات عادةً باستخدام ترميز ديراك (كيت) - Dirac (ket) notation، مثل $|0\rangle$ و $|1\rangle$، وهي تتبع مبادئ ميكانيكا الكم
# </div>
# <div dir="rtl" style="text-align: right;">
# ميكانيكا الكم هي " دراسة الفيزياء على نطاقات صغيرة للغاية، وتكشف عن مبادئ الطبيعة الأساسية المدهشة." (Translated from - تم ترجمتها من [1])
# </div>
# <div dir="rtl" style="text-align: right;">
# كما تتمتع البتات الكمومية بخصائص فريدة وقوية أخرى، والتي سنستكشفها في الجلسات القادمة.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 1.2: التراكب — Superposition
# </div>
# <div dir="rtl" style="text-align: right;">
#  يمكن للبت الكمومي وضع المعلومات الكمومية التي يحملها في تراكب كمومي، والذي يمثل جميع التركيبات الممكنة لتكوينات البت الكمومي. (adapted and translated from - تم ترجمتها واقتباسها من [1])
# </div>
# <div dir="rtl" style="text-align: right;">
# تُعد هذه إحدى المزايا الرئيسية مقارنةً بالبتات الكلاسيكية.
# </div>
# <div dir="rtl" style="text-align: right;">
# تشبيه بسيط يجعلك تفكر بشكل صحيح في التراكب:
# </div>
# <div dir="rtl" style="text-align: right;">
# افترض أن لديك عملة معدنية وقمت بترميزها على النحو التالي - صورة (الحالة $|0\rangle$)، كتابة (الحالة $|1\rangle$) - ثم رميتها في السماء.
# </div>
# <div dir="rtl" style="text-align: right;">
# يحدث التراكب عندما تكون العملة في الهواء: يمكن أن تكون إما صورة ($|0\rangle$)، أو كتابة ($|1\rangle$)، أو كليهما - وهو التراكب - حتى نقيسه (هنا: عندما تسقط العملة في يدك)، وتحصل على إما صورة ($|0\rangle$) أو كتابة ($|1\rangle$).
# </div>
# <div dir="rtl" style="text-align: right;">
# وبالتالي، تنهار حالة التراكب إلى حالة واحدة عند القياس. (adapted and translated from - تم اقتباسها وترجمتها من [1])
# </div>
# <div dir="rtl" style="text-align: right;">
# يتم التعبير عنا رياضيًا على النحو التالي:
# </div>
# <div dir="rtl" style="text-align: right;">
# .$|\psi\rangle = \alpha|0\rangle + \beta|1\rangle$
# </div>
# <div dir="rtl" style="text-align: right;">
# حيثُ أن:
# </div>
# <div dir="rtl" style="text-align: right;">
# $|\psi\rangle$: الدالة الموجية.
# </div>
# <div dir="rtl" style="text-align: right;">
# $\alpha$: المعامل (السعة الاحتمالية) للحالة $|0\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# $\beta$: المعامل (السعة الاحتمالية) للحالة $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# <div dir="rtl" style="text-align: right;">
# لن نخوض في تفاصيل الرياضيات هنا، فهذا الدفتر لا يركز على الجانب الرياضي بعمق، بل على فهم المفاهيم الأساسية.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 1.3: التشابك — Entanglement
# </div>
# <div dir="rtl" style="text-align: right;">
# يُعد التشابك من أهم خصائص الكيوبتات.
# </div>
# <div dir="rtl" style="text-align: right;">
# عندما يكون كيوبتان متشابكين، فإنهما سيكونان في الحالة نفسها، مما يُكوّن لنا نظامًا متشابكًا. (adapted and translated from - تم اقتباسها وترجمتها من [1])
# </div>
# <div dir="rtl" style="text-align: right;">
# عندما نقيس أحد أجزاء النظام المتشابك (الكيوبت المتشابك) لتحديد حالته، يمكننا معرفة حالة الجزء الآخر (الكيوبت المتشابك الآخر) من خلال الكيوبت الذي قمنا بقياسه. (adapted and translated from - تم اقتباسها وترجمتها من [1])
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## الفصل 2 — البوابات الكمومية
# </div>
# <div dir="rtl" style="text-align: right;">
# أولاً، نحتاج إلى استيراد المكتبات المطلوبة والبدء في استكشاف البوابات الكمومية من الناحيتين النظرية والعملية.
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ##### ملاحظة: بعض أمثلة الأكواد مقتبسة ومترجمة من [2] لعرض عدة بوابات كمومية باستخدام دارة كمومية واحدة.
# </div>
#
#
# ##### Note: Some of the code examples are adapted and translated from [2] to demonstrate multiple quantum gates using a single quantum circuit.

# %%
#Importing Required libraries
#استيراد المكتبات المطلوبة
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit import transpile
from qiskit.visualization import plot_histogram


#We give the name qu_circuit(shortcut for quantum circuit) for our quantum circuit.
#Important note:  It doesn't matter the name of the circuit this is only for make it clear for you.

#نسمي الدارة الكمومية الخاصة بنا qu_circuit (اختصار لـ quantum circuit).
#ملاحظة مهمة: لا يهم اسم الدارة، فهذه التسمية فقط لتوضيح الأمور لك.

#Here creating a two qubit quantum circuit
#هنا نقوم بإنشاء دارة كمومية مكونة من كيوبتين (بتين كموميين)
qu_circuit = QuantumCircuit(2)

#رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 2.1: بوابة $X$
# </div>
# <div dir="rtl" style="text-align: right;">
# بوابتنا الأولى للمناقشة في هذا الدفتر.
# </div>
# <div dir="rtl" style="text-align: right;">
# بوابة **$X$ (NOT)** هي بوابة كيوبت واحد، وعندما يتم تطبيقها على كيوبت فإنها تقلّب حالته.
# </div>
# <div dir="rtl" style="text-align: right;">
# عند تطبيق بوابة $X$ على الحالة $|0\rangle$، تكون النتيجة: $|1\rangle$. (adapted and translated from - تم اقتباسها وترجمتها من [2])
# </div>
# <div dir="rtl" style="text-align: right;">
# عند تطبيق بوابة $X$ على الحالة $|1\rangle$، تكون النتيجة: $|0\rangle$. (adapted and translated from - تم اقتباسها وترجمتها من [2])
# </div>
# <div dir="rtl" style="text-align: right;">
# إذاً، العملية مشابهة لبوابة الـ NOT الكلاسيكية، والمعروفة أيضًا باسم قَلّب البت. (adapted and translated from - تم اقتباسها وترجمتها من [2])
# </div>

# %%
#Here is the Python code of applying X gate
#كود (رمز برمجي) بايثون لتطبيق بوابة X.

#First Create our single qubit Quantum Circuit
#أولًا، نقوم بإنشاء دائرة كمومية مكونة من كيوبت واحد
qu_circuit = QuantumCircuit(1)

#Apply X gate on qubit one(indexed as 0) → flip the state from |0⟩ to |1⟩
#تطبيق بوابة X على الكيوبت الأول (معرّف برقم 0) ← قلب الحالة من  ∣0⟩ إلى ∣1⟩ 
qu_circuit.x(0) 

#رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
# "في IBM Quantum، الحالة الابتدائية تكون مهيأة على الحالة $|0\rangle$". (translated from - تم ترجمتها من [2])
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث في الأعلى؟
# </div>
# <div dir="rtl" style="text-align: right;">
# ما حدث أعلاه أن الكيوبت مهيأ افتراضيًا في الحالة $|0\rangle$، وقمنا بتطبيق بوابة $X$ عليه، فتم قلب حالته إلى الحالة $|1\rangle$.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 2.2: بوابة هادامارد — Hadamard
# </div>
# <div dir="rtl" style="text-align: right;">
# بوابة هادامارد (H) هي بوابة كيوبت واحد، وعند تطبيقها على كيوبت، فإنها تحوله إلى حالة تراكب كمومي.
# </div>
# <div dir="rtl" style="text-align: right;">
# عند تطبيق بوابة H على الحالة $|0\rangle$، فإنها تُنشئ حالة تراكب بين $|0\rangle$ و $|1\rangle$، ويُعبر عن ذلك رياضيًا كما يلي: $H|0\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}} \quad$ (adapted and translated from - تم اقتباسها وترجمتها من [2])
# </div>
# <div dir="rtl" style="text-align: right;">
# عند تطبيق بوابة H على الحالة $|1\rangle$، فإنها تُنشئ حالة تراكب بين $|0\rangle$ و $|1\rangle$، ويُعبر عن ذلك رياضيًا كما يلي: $H|1\rangle = \frac{|0\rangle - |1\rangle}{\sqrt{2}}$ (adapted and translated from - تم اقتباسها وترجمتها من [2])
# </div>

# %%
#Here is the python code of applying H gate
#كود (رمز برمجي) بايثون لتطبيق بوابة H.

#First Create our single qubit Quantum Circuit
#أولًا، نقوم بإنشاء دائرة كمومية مكونة من كيوبت واحد
qu_circuit = QuantumCircuit(1)

#Apply Hadamard gate on qubit one(indexed here as (0)) → creates superposition
# تطبيق بوابة هادامارد على الكيوبت الأول (معرّف برقم 0) ← إنشاء حالة تراكب كمومي
qu_circuit.h(0)

#رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث في الأعلى؟
# </div>
# <div dir="rtl" style="text-align: right;">
# ما حدث أعلاه أن الكيوبت مهيأ افتراضيًا في الحالة $|0\rangle$، وقمنا بتطبيق بوابة هادامارد H عليه.
# </div>
# <div dir="rtl" style="text-align: right;">
# هذا يؤدي إلى إنشاء حالة تراكب تجمع بين $|0\rangle$ و $|1\rangle$ في الوقت نفسه.
# </div>
# <div dir="rtl" style="text-align: right;">
# يُعبر عن ذلك رياضيًا (من [2]) كما يلي:  $H|0\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}} \quad$
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; margin-top: 1em;"> <div class="alert alert-block alert-success">
#     <b>تمرين 1: تحويل التعبير الرياضي إلى دارة كمومية</b><br><br>
# <b>ماذا تفعل؟</b>
# عليك تحويل التعبير الرياضي
# "$H|1\rangle = \frac{|0\rangle - |1\rangle}{\sqrt{2}}$"
# إلى دارة كمومية.
#
# </div> <div class="alert alert-info"> <details> <summary><b>أوجد التلميح في السؤالين</b> (اضغط للتوسيع)</summary> <ul> <li>هل تذكر ما ناقشناه سابقًا في جلسة بوابة X؟</li> <li>هل تذكر ماذا تفعل بوابة هادامارد عند تطبيقها على الحالات $|0\rangle$ و $|1\rangle$ ؟ ماذا نحصل كنتيجة؟</li> </ul> </details> </div> </di

# %%
#أولًا، نقوم بإنشاء دائرة كمومية مكونة من كيوبت واحد
qu_circuit = QuantumCircuit(1)

#تلميح آخر: قم بتطبيق البوابتين بالتتابع على الكيوبت



#رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div class="alert alert-info" dir="rtl" style="text-align: right;">
# <details>
#     <summary><b>يجب أن تكون إجابتك كما يلي:</b> (اضغط للتوسيع)</summary>
#
# <pre>
# # Here creating our single qubit quantum circuit
# # هنا ننشئ دارة كمومية مكونة من كيوبت واحد
# qu_circuit = QuantumCircuit(1)
#
#
# # تلميح آخر: طبّق البوابتين بالتتابع على نفس الكيوبت
#
# # Apply X gate to flip the state from |0⟩ to |1⟩
# # تطبيق بوابة X لقلب الحالة من |0⟩ إلى |1⟩
# qu_circuit.x(0)
#
# # Apply Hadamard gate → creates superposition(H|1⟩ = (|0⟩ - |1⟩)/√2):
# # تطبيق بوابة هادامارد ← لإنشاء حالة تراكب (H|1⟩ = (|0⟩ - |1⟩)/√2)
# qu_circuit.h(0)
#
# # رسم الدارة
# qu_circuit.draw('mpl')
#
# </pre>
#
# </details>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 2.3: بوابة CNOT
# </div>
# <div dir="rtl" style="text-align: right;">
# "بوابة CNOT (وتُعرف أيضًا باسم Controlled NOT أو CX) هي بوابة مكونة من كيوبتين، أي أن عملها يتضمن كيوبتين في وقت واحد: كيوبت التحكم (controlled qubit)  والكيوبت المستهدف (target qubit) ". (translated from - تم ترجمتها من [2])
# </div>
# <div dir="rtl" style="text-align: right;">
# تقوم بوابة CNOT بقلّب (تطبيق بوابة X (NOT) على) كيوبت الهدف فقط إذا كانت حالة كيوبت التحكم هي $|1\rangle$. (adapted and translated from - تم اقتباسها وترجمتها من [2])
# </div>

# %%
#Here is the Python code of applying CNOT gate
#كود (رمز برمجي) بايثون لتطبيق بوابة CNOT.

#First Create our two qubit Quantum Circuit
#هنا نقوم بإنشاء دارة كمومية مكونة من كيوبتين (بتين كموميين)
qu_circuit = QuantumCircuit(2)

#Apply CNOT gate → (Control qubit, target qubit)
# تطبيق بوابة CNOT → (الكيوبت المستهدف ,كيوبت التحكم)
qu_circuit.cx(0,1) 

#رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث في الأعلى؟
# </div>
# <div dir="rtl" style="text-align: right;">
# ماحدث أعلاه أننا قمنا بتطبيق بوابة CNOT حيثُ أن:
# </div>
# <div dir="rtl" style="text-align: right;">
#
# - كيوبت 1 (q0) هو الكيوبت المتحكم.
# - كيوبت 2 (q1) هو الكيوبت المستهدف.
# </div>
# <div dir="rtl" style="text-align: right;">
# بما أن كلا الكيوبتين مُهيَّآن افتراضيًا في الحالة $|0\rangle$،
# </div>
# <div dir="rtl" style="text-align: right;">
# لأن كيوبت التحكم في الحالة $|0\rangle$، فإن بوابة CNOT لن تُحدِث أي تأثير(لن تطبق بوابة
# X على الكيوبت المستهدف).
# </div>
# <div dir="rtl" style="text-align: right;">
# تبقى الحالة النهائية للنظام كما هي: $|00\rangle$
# </div>
# <div dir="rtl" style="text-align: right;">
# قبل الانتقال إلى الخطوة التالية، سنقوم بإجراء عملية القياس على بعض الدارات الكمومية التي أنشأناها سابقًا للتحقق من نتائجها:
# </div>

# %%
#First Create our single qubit Quantum Circuit and  one classical bit (cbit) to store the result of the measurement
#أولًا، نقوم بإنشاء دارة كمومية من كيوبت واحد وبت كلاسيكي واحد لتخزين نتيجة القياس

qu_circuit = QuantumCircuit(1,1)

# Apply the X gate on qubit 1 (indexed as 0) → flips from |0⟩ to |1⟩
# تطبيق بوابة X على الكيوبت الأول (معرّف بالرقم 0) ← قلب الحالة من |0⟩ إلى |1⟩
qu_circuit.x(0)

# Measure qubit 1 (indexed as 0) and store it in classical bit 1 (indexed as 0)
# قياس الكيوبت الأول (معرّف بالرقم 0) وتخزين النتيجة في البت الكلاسيكي الأول (معرّف بالرقم 0)
qu_circuit.measure(0, 0) 

# رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث في الأعلى؟
# </div>
# <div dir="rtl" style="text-align: right;">
# كان الكيوبت مهيأً في البداية في الحالة $|0\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# بعد تطبيق بوابة X، تقلّبت الحالة من $|0\rangle$ إلى $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# عند القياس، نحصل دائمًا على القيمة 1 كنتيجة، لأن الكيوبت أصبح في حالة مؤكدة $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# الآن، دعونا نقوم بقياس دارة هادامارد الكمومية التي استعرضناها سابقًا:
# </div>

# %%
#First Create our single qubit Quantum Circuit and  1 classical bit (cbit) to store the result of the measurement
#أولًا، نقوم بإنشاء دارة كمومية من كيوبت واحد وبت كلاسيكي واحد لتخزين نتيجة القياس
qu_circuit = QuantumCircuit(1,1)

#Apply Hadamard gate on qubit one(indexed here as 0) → creates superposition
# تطبيق بوابة هادامارد على الكيوبت الأول (معرّف برقم 0) ← إنشاء حالة تراكب كمومي
qu_circuit.h(0) 

#Measure qubit 1 (indexed as 0) and store it in classical bit 1 (indexed as 0)
# قياس الكيوبت الأول (معرّف بالرقم 0) وتخزين النتيجة في البت الكلاسيكي الأول (معرّف بالرقم 0)
qu_circuit.measure(0, 0) 

# رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث في الأعلى؟
# </div>
# <div dir="rtl" style="text-align: right;">
# بعد تطبيق بوابة هادامارد على كيوبت مهيأ في البداية في الحالة $|0\rangle$، يصبح الكيوبت في حالة تراكب بين $|0\rangle$ و $|1\rangle$، ويُعبر عن ذلك رياضيًا (من [2]) كما يلي:
# </div>
# <div dir="rtl" style="text-align: right;">
# $H|0\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}} \quad$
# </div>
# <div dir="rtl" style="text-align: right;">
# هذا يشير إلى أن الكيوبت يتواجد في كلتا الحالتين في آنٍ واحد، مع احتمال متساوٍ بنسبة 50% لظهوره في كل حالة عند القياس.
# </div>
# <div dir="rtl" style="text-align: right;">
# ومع ذلك، عند القياس، تنهار حالة التراكب إلى حالة واحدة محددة:</div>
# <div dir="rtl" style="text-align: right;">
# فرصة بنسبة 50% للحصول على الحالة $|0\rangle$ عند القياس.
# </div>
# <div dir="rtl" style="text-align: right;">
# فرصة بنسبة 50% للحصول على الحالة $|1\rangle$ عند القياس.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; margin-top: 1em;"> <div class="alert alert-block alert-success">
# <b>تمرين 2: جرّب قياس دارة كمومية مكونة من كيوبتين بنفسك!</b><br><br>
# <b>ماذا تفعل؟</b>
# قم بتطبيق بوابة X على الكيوبت الأول، ثم طبّق بوابة CNOT على الدارة،
# حيث يكون الكيوبت الأول هو الكيوبت المتحكم (control)، والكيوبت الثاني هو الكيوبت المستهدف (target).
# في النهاية، قم بقياس الكيوبتين لاستكشاف النتائج التي تحصل عليها.
#
# </div>

# %%
#First Create our two qubits Quantum Circuit and  2 classical bits (cbits) to store the result of the measurements
#أولًا، نقوم بإنشاء دارة كمومية من كيوبتين (بتين كموميين) وبتين كلاسيكيين لتخزين نتائج القياسات

qu_circuit = QuantumCircuit(2,2)

#Here write your code
#هنا أُكتب الكود (الرمز البرمجي) الخاص بك


#Here measure your circuit
# هنا قم بقياس الدارة الكمومية الخاصة بك


qu_circuit.measure(0, 0) #Don't forget when measuring a qubits you need to use a classical bits to store the result 
                         # لا تنسَ أنه عند قياس الكيوبتات يجب استخدام بتات كلاسيكية لتخزين النتيجة
                        #Measure qubit 2 and store it on classical bit two - قياس الكيوبت الثاني وتخزينه في البت الكلاسيكي الثاني

# رسم الدارة
qu_circuit.draw('mpl')

# %% [markdown]
# <div class="alert alert-info" dir="rtl" style="text-align: right;">
# <details>
#     <summary><b>يجب أن تكون إجابتك كما يلي:</b> (اضغط للتوسيع)</summary>
#
# <pre>
# #First Create our two qubits Quantum Circuit and  2 classical bits (cbits) to store the result of the measurements
# #أولًا، نقوم بإنشاء دارة كمومية من كيوبتين (بتين كموميين) وبتين كلاسيكيين لتخزين نتائج القياسات
#
# qu_circuit = QuantumCircuit(2,2)
#
# #Here write your code
# #هنا أُكتب الكود (الرمز البرمجي) الخاص بك
#
# qu_circuit.x(0)      # Apply the X gate on qubit 1 (indexed as 0) → flips from |0⟩ to |1⟩ - # تطبيق بوابة X على الكيوبت الأول (معرّف بالرقم 0) ← قلب الحالة من |0⟩ إلى |1⟩
#
#
# qu_circuit.cx(0, 1)  #Apply CNOT gate → (Control qubit, target qubit) - # تطبيق بوابة CNOT → (الكيوبت المستهدف ,كيوبت التحكم)
#
# #Here measure your circuit
# # هنا قم بقياس الدارة الكمومية الخاصة بك
#
# qu_circuit.measure(0, 0) #Don't forget when measuring a qubits you need to use a classical bits to store the informations
#                          # لا تنسَ أنه عند قياس الكيوبتات يجب استخدام بتات كلاسيكية لتخزين النتيجة
#
# qu_circuit.measure(1, 1) #Measure qubit 2 and store it on classical bit two - قياس الكيوبت الثاني وتخزينه في البت الكلاسيكي الثاني
#
# #رسم الدارة
# qu_circuit.draw('mpl')
# </pre>
#
# </details>
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث في الأعلى؟
# </div>
# <div dir="rtl" style="text-align: right;">
# بعد تطبيق بوابة X على الكيوبت الأول (q0)، تصبح حالته$|1\rangle$، بينما يبقى الكيوبت الثاني (q1) في الحالة$|0\rangle$، لتصبح الحالة الكلية للنظام $|01\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# بعد ذلك، نُطبق بوابة CNOT بحيث يكون الكيوبت الأول (q0) هو الكيوبت المتحكّم، والكيوبت الثاني (q1) هو الكيوبت المستهدف.
# </div>
# <div dir="rtl" style="text-align: right;">
# نظرًا لأن الكيوبت المتحكّم في الحالة $|1\rangle$، فإن بوابة CNOT تقوم بقلّب حالة الكيوبت المستهدف من $|0\rangle$ إلى $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# وبذلك تصبح الحالة النهائية للنظام $|11\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# إذًا عند قياس كلا الكيوبتين، نحصل دائمًا على النتيجة: $|11\rangle$.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## الفصل 3 — بناء دارتك الكمومية الأولى باستخدام كيسكت من الصفر
# </div>
# <div dir="rtl" style="text-align: right;">
# قبل بناء أول دائرة كمومية لك، دعنا نُقدّم بإيجاز مفهومين أساسيين:
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 3.1: محاكي Aer
# </div>
# <div dir="rtl" style="text-align: right;">
# محاكي Aer (من مكتبة كيسكت) هو أداة تسمح لنا بمحاكاة الدارات الكمومية على الحواسيب الكلاسيكية.
# </div>
# <div dir="rtl" style="text-align: right;">
# يُساعدنا هذا المحاكي على مراقبة النتائج وتمثيلها بيانيًا قبل تشغيل الدارات على العتاد الكمومي الحقيقي.
# </div>
# <div dir="rtl" style="text-align: right;">
# الآن، لنقم بتشغيل مثال بوابة هادامارد السابق باستخدام محاكي Aer.
# </div>
#
# ##### Note: The Aer simulator code used here is adapted and translated from reference **[2]**.
# <div dir="rtl" style="text-align: right;">
#
# ##### ملاحظة: كود محاكي Aer المستخدم هنا مقتبس وتمت ترجمته من المرجع [2].
# </div>

# %%
#First Create our single qubit Quantum Circuit and  1 classical bit (cbit) to store the result of the measurement
#أولًا، نقوم بإنشاء دارة كمومية من كيوبت واحد وبت كلاسيكي واحد لتخزين نتيجة القياس
qu_circuit = QuantumCircuit(1,1)

#Apply Hadamard gate on qubit one(indexed here as 0) → creates superposition
# تطبيق بوابة هادامارد على الكيوبت الأول (معرّف برقم 0) ← إنشاء حالة تراكب كمومي
qu_circuit.h(0) 

#Measure qubit 1 (indexed as 0) and store  the result in classical bit 1 (indexed as 0)
# قياس الكيوبت الأول (معرّف بالرقم 0) وتخزين النتيجة في البت الكلاسيكي الأول (معرّف بالرقم 0)
qu_circuit.measure(0, 0) 

#رسم الدارة
qu_circuit.draw('mpl')

# %%
#Run our quantum circuit above using Aer simulator - تشغيل الدارة الكمومية أعلاه باستخدام محاكي Aer
simulator = AerSimulator() #Building Aer Simulator - بناء محاكي Aer

#Preparing the quantum circuit (using "transpile") to run on the Aer simulator
## تهيئة (تحويل) الدارة الكمومية (باستخدام "transpile") لتشغيلها على محاكي Aer

transpiled_circuit = transpile(qu_circuit, simulator) # transpile(our circuit, simulator that we build above) - transpile(المحاكي التي تم بناءه بالأعلى, دارتنا)


#Run the simulator - تشغيل المحاكي
result = simulator.run(transpiled_circuit,shots=1000).result() #we here run the circuit 1000 times (shots) and get the result
# بالأعلى نقوم بتشغيل الدارة 1000 مرة (shots) للحصول على النتيجة

#get counts - الحصول على عدد مرات ظهور كل ناتج (counts)
counts = result.get_counts()

print(counts) # طباعة النتائج (counts)

#Draw the Histogram - رسم الهيستوجرام
plot_histogram(counts)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث هنا؟
# </div>
# <div dir="rtl" style="text-align: right;">
# بعد تطبيق بوابة هادامارد على الكيوبت 1، تتحول حالته من $|0\rangle$ إلى حالة تراكب كمومي:
# </div>
# <div dir="rtl" style="text-align: right;">
# $H|0\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}}$
# </div>
# <div dir="rtl" style="text-align: right;">
# وهذا يعني وجود احتمال 50% لقياس الحالة $|0\rangle$ واحتمال 50% لقياس الحالة $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# عند القياس، تنهار حالة التراكب إلى إحدى الحالتين $|0\rangle$ أو $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# وبعد تشغيل الدائرة الكمومية 1000 مرة (shots = 1000)، نحصل عادةً على التوزيع التقريبي التالي:
# </div>
# <div dir="rtl" style="text-align: right;">
# {′0′:∼500, ′1′:∼500}.
# </div>
# <div dir="rtl" style="text-align: right;">
# وبالتالي، يُظهر الرسم البياني التوزيع المتوازن تقريبًا بين القيمتين 0 و1.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 3.2: حالة بيل (Bell)
# </div>
# <div dir="rtl" style="text-align: right;">
# "في نظرية المعلومات الكمومية، تُعد حالة بيل (Bell State) حالة كمومية محددة لزوج من الكيوبتات، وتمثل أبسط وأشهر مثال على التشابك الكمومي." (translated from - تم ترجمتها من [3])
# </div>
# <div dir="rtl" style="text-align: right;">
# ويُعبر عنها رياضيًا (من [3]) كما يلي:
# </div>
# <div dir="rtl" style="text-align: right;">
# $|\Phi^+\rangle = \frac{|00\rangle + |11\rangle}{\sqrt{2}}$
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right; margin-top: 1em;"> <div class="alert alert-block alert-success"> <b>تمرين 3: ابني دائرتك الكمومية الأولى باستخدام كيسكت من الصفر!</b><br><br>
# <b>شرح مختصر:</b><br>
#
# <ul> <li>أولاً، عليك إنشاء دائرة كمومية تحتوي على <b>كيوبتين</b> و<b>بتين كلاسيكيين</b> لتخزين نتائج القياس.<br> من المهم تسمية الدائرة الكمومية بـ <code>bell_circuit</code>.</li><br> <li>ثانيًا، طبق بوابة <b>هادامارد (Hadamard)</b> على الكيوبت 1 (<code>q0</code>).</li><br> <li>ثالثًا، طبق بوابة <b>CNOT</b> بحيث يكون الكيوبت 1 (<code>q0</code>) هو الكيوبت المسيطر، والكيوبت 2 (<code>q1</code>) هو الكيوبت المستهدف.</li><br> <li>اختياريًا، يمكنك قياس كلا الكيوبتين ورسم الدائرة الكمومية.</li> </ul>
# <b>ماذا تفعل؟</b><br>
# الآن دورك لبناء دائرتك الكمومية الأولى من الصفر.
# بالتوفيق!
#
# </div> </div>

# %%
#Build your quantum circuit here:
#أبنِ دارتك الكمومية هنا

# %% [markdown]
# <div class="alert alert-info" dir="rtl" style="text-align: right;">
# <details>
#     <summary><b>يجب أن تكون إجابتك كما يلي:</b> (اضغط للتوسيع)</summary>
#
# <pre>
# # First, creating our two qubit quantum circuit, with two classical bits to store the results of the measurements
# #أولًا، نقوم بإنشاء دارة كمومية من كيوبتين (بتين كموميين) وبتين كلاسيكيين لتخزين نتائج القياسات
# bell_circuit = QuantumCircuit(2,2)
#
# #Apply Hadamard gate on qubit one(indexed here as 0) → creates superpositio
# # تطبيق بوابة هادامارد على الكيوبت الأول (معرّف برقم 0) ← إنشاء حالة تراكب كمومي
# bell_circuit.h(0)
#
# #Apply CNOT gate → (Control qubit, target qubit) → make the qubits entangled
# # تطبيق بوابة CNOT → (الكيوبت المستهدف، الكيوبت المتحكم) → لجعل الكيوبتين متشابكين
# bell_circuit.cx(0,1)
#
# #Optional: Measurements and Drawing - اختياري: إجراء القياسات ورسم الدارة
#
# #Measure the qubits - قياس الكيوبتات
# # قياس الكيوبت الأول وتخزين النتيجة في البت الكلاسيكي الأول
# bell_circuit.measure(0,0) #Measure qubit 1 (indexed as 0) and store the result in classical bit 1 (indexed as 0)
#
# # قياس الكيوبت الثاني وتخزين النتيجة في البت الكلاسيكي الثاني
# bell_circuit.measure(1,1) #Measure qubit 2 (indexed as 1) and store the result in classical bit 2 (indexed as 1)
#
# # رسم الدارة
# bell_circuit.draw('mpl')
# </pre>
#
# </details>
# </div>

# %%
#Run our quantum circuit above using Aer simulator -  تشغيل الدارة الكمومية أعلاه باستخدام محاكي Aer
simulator = AerSimulator() #Building Aer Simulator - بناء محاكي Aer

#Preparing the quantum circuit (using "transpile") to run on the Aer simulator
# تهيئة (تحويل) الدارة الكمومية (باستخدام "transpile") لتشغيلها على محاكي Aer
transpiled_circuit = transpile(bell_circuit, simulator) # transpile(our circuit, simulator that we build above) - transpile(المحاكي التي تم بناءه بالأعلى, دارتنا)

#Run the simulator - تشغيل المحاكي
result = simulator.run(transpiled_circuit,shots=1000).result() #we here run the circuit 1000 times (shots) and get the result
# بالأعلى نقوم بتشغيل الدارة 1000 مرة (shots) للحصول على النتيجة

#get counts - الحصول على عدد مرات ظهور كل ناتج (counts)
counts = result.get_counts()

print(counts) # طباعة النتائج (counts)

#Draw the Histogram - رسم الهيستوجرام
plot_histogram(counts)

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ##### ماذا حدث هنا؟
# </div>
# <div dir="rtl" style="text-align: right;">
# قمنا ببناء دارة حالة بيل من الصفر:
# </div>
# <div dir="rtl" style="text-align: right;">
# طبقنا بوابة هادامارد على الكيوبت 1 (q0)، مما وضعه في حالة تراكب:
# </div>
# <div dir="rtl" style="text-align: right;">
# $H|0\rangle = \frac{|0\rangle + |1\rangle}{\sqrt{2}}$ (من [2])
# </div>
# <div dir="rtl" style="text-align: right;">
# ثم طبقنا بوابة CNOT بحيث يكون الكيوبت 1 (q0) هو المسيطر والكيوبت 2 (q1) هو المستهدف.
# هذا تسبب في تشابك الكيوبتين وإنشاء حالة بيل:
# </div>
# <div dir="rtl" style="text-align: right;">
# $|\Phi^+\rangle = \frac{|00\rangle + |11\rangle}{\sqrt{2}}$ (من [3])
# </div>
# <div dir="rtl" style="text-align: right;">
# عند قياس الكيوبتين مرات عديدة (shots)، نتوقع الحصول على إما $|00\rangle$ أو $|11\rangle$ باحتمالية متساوية تقريبًا.
# </div>
# <div dir="rtl" style="text-align: right;">
# هذا يعني:
# </div>
# <div dir="rtl" style="text-align: right;">
# إذا تم قياس الكيوبت الأول على الحالة $|0\rangle$، فسيكون الكيوبت الثاني أيضًا في الحالة $|0\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# إذا تم قياس الكيوبت الأول على الحالة $|1\rangle$، فسيكون الكيوبت الثاني أيضًا في الحالة $|1\rangle$.
# </div>
# <div dir="rtl" style="text-align: right;">
# هذه النتائج المرتبطة تمثل خاصية التشابك الكمومي، وهي السمة المميزة له.
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# #### تهانينا! 🎉
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ##### لقد قمت ببناء أول دارة كمومية لك من الصفر!
# </div>

# %% [markdown]
# <div dir="rtl" style="text-align: right;">
#
# ## الفصل 4 — 🎯 الختام
# </div>
# <div dir="rtl" style="text-align: right;">
# هل هذا يعني أنك الآن مطور كمومي رسميًا؟ 😄
# </div>
# <div dir="rtl" style="text-align: right;">
# أنا أمزح فقط! (أو ربما لا...)
# </div>
# <div dir="rtl" style="text-align: right;">
# في كل الأحوال، وصولك إلى هذه النقطة إنجاز كبير — أحسنت!
# </div>
# <div dir="rtl" style="text-align: right;">
# في هذا الدفتر، أخذت أولى خطواتك في عالم الحوسبة الكمومية.
# </div>
# <div dir="rtl" style="text-align: right;">
# تعلمت كلًا من الأساسيات النظرية والتطبيقة لأهم المفاهيم الكمومية باستخدام Qiskit، بما في ذلك:
# <ul>
# <li>ما هي الحوسبة الكمومية وكيف تختلف عن الحوسبة الكلاسيكية</li>
# <li>كيف يمكن للكيوبتات أن تكون في حالة تراكب</li>
# <li>ما هو التشابك ولماذا هو مهم</li>
# <li>دور البوابات الكمومية مثل X و H و CNOT</li>
# <li>كيف تبني الدوائر وتحاكيها باستخدام AerSimulator</li>
# <li>كيف تقيس الحالات الكمومية وتفسر النتائج</li>
# <li>وأخيراً... كيف تبني أول دائرة كمومية كاملة: حالة بيل 🎉</li>
# </ul>
# </div>
#
#
# ---
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 4.1: 🧠 هل وجدت هذا مفيدًا؟
# </div>
# <div dir="rtl" style="text-align: right;">
# إذا كانت الإجابة نعم، يسعدني سماع رأيك.
# </div>
# <div dir="rtl" style="text-align: right;">
# يرجى تخصيص دقيقة لملء نموذج الملاحظات — سيساعدني ذلك على معرفة مدى الاستفادة وكيفية التحسين:
# </div>
# <div dir="rtl" style="text-align: right;">
# 📬 <b><a href="https://forms.gle/sgQ1TVHpJ2TqF6u8A">اضغط هنا لمشاركة رأيك</a></b>
# </div>
#
#
# ---
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 4.2: 📚 مصادر مفتوحة مفيدة:
# <ul>
# <li><a href="https://www.thomaswong.net/introduction-to-classical-and-quantum-computing-1e4p.pdf">Introduction to Classical and Quantum Computing by Thomas Wong - كتاب</a></li>
# <li><a href="https://quantum.cloud.ibm.com/learning/en">منصة IBM Quantum Learning</a></li>
# <li><a href="https://qiskit.org/documentation/">توثيق Qiskit</a></li>
# <li><a href="https://quantum-computing.ibm.com/">مختبر IBM Quantum</a></li>
# <li><a href="https://arxiv.org/abs/2507.11536">Understanding Quantum Information and Computation by John Watrous - كتاب</a></li>
# <li><a href="https://www.youtube.com/channel/UClBNq7mCMf5xm8baE_VMl3A">قناة Qiskit على يوتيوب</a></li>
# </ul>
# </div>
#
#
# ---
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 4.3: 🔍 المراجع:
# <ul>
#
# <li><a href="https://www.ibm.com/think/topics/quantum-computing">[1]: https://www.ibm.com/think/topics/quantum-computing</a></li>
# <li><a href="https://quantum.cloud.ibm.com/learning/en/courses/utility-scale-quantum-computing/bits-gates-and-circuits">[2]: https://quantum.cloud.ibm.com/learning/en/courses/utility-scale-quantum-computing/bits-gates-and-circuits</a></li>
# <li><a href="https://en.wikipedia.org/wiki/Bell_state">[3]: https://en.wikipedia.org/wiki/Bell_state</a></li>
# Note: Content related to *Bell State* is partially adapted and translated from [Wikipedia][3], licensed under <a href="https://creativecommons.org/licenses/by-sa/4.0/">CC BY-SA 4.0</a>
# </ul>
# </div>
#
#
# ---
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 4.4: 🙏 شكر خاص
# </div>
# <div dir="rtl" style="text-align: right;">
# شكراً جزيلاً لمؤلفي المصادر المفتوحة،
# </div>
# <div dir="rtl" style="text-align: right;">
# ولكل من يساهم في جعل الحوسبة الكمومية أكثر إتاحة للعالم.
# </div>
#
#
# ---
# <div dir="rtl" style="text-align: right;">
# مع خالص التحية،
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ##### حسان الحصيني
# </div>
# <div dir="rtl" style="text-align: right;">
# صديقك مطور الكم المبتدئ ⚛️🤍
# </div>
# <div dir="rtl" style="text-align: right;">
# 📬 تواصل معي:
# <ul>
# <li><a href="https://www.linkedin.com/in/hassan-alhusayni/">LinkedIn</a></li>
# <li><a href="https://github.com/Hassan-Alhusayni">GitHub</a></li>
# <li><a href="hassansulaiman1719@gmail.com">Email</a></li>
# <li><a href="https://medium.com/@hassansulaiman1719">Medium</a></li>
# <li><a href="https://dev.to/hassanalhusayni">Dev.to</a></li>
# <li><a href="https://x.com/I1Hassan1">X(Twitter)</a></li>
# </ul>
# </div>
#
#
# ---
# <div dir="rtl" style="text-align: right;">
#
# ### جلسة 4.5: الوداع من صديقك الكمومي ⚛️:
# </div>
# <div dir="rtl" style="text-align: right;">
#
# ##### "حيوووووو....بالنوب!"
# </div>
# <div dir="rtl" style="text-align: right;">
# بس ترى مو أي نوب… أنت الآن النوب اللي يعرف التراكب وفعل التشابك الكمومي،
# وبنى دائرة حالة بيل من الصفر 😎⚛️
# </div>
# <div dir="rtl" style="text-align: right;">
# هذا يخليك رسميًا:
# </div>
#
# > **Certified Quantum Noob™ — but dangerous.**
